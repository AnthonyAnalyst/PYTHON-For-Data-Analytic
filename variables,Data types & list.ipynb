# %% [markdown]
# # variables,Data types & list
#
# ## 1. variables

# %%
name ="olara Anthony"
print(name)
# Out:
# olara Anthony

# %%
age = 26
course = "data analytics"
height = 2.34
gender = "male"
print(age)
# Out:
# 26

# %%
# Python is a case senstive
#Age,age,AGE

# %%
#camel casing
myFirstName ='Anthony'

# %%
#Sneke case
my_fist_name = 'olara'

# %%
age = 28
name = "Sarah"
salary = 55000.50
print(name)
print(age)
print(salary)
# Out:
# Sarah
# 28
# 55000.5

# %% [markdown]
# ## 2. Date types
#
#
# ###  a. Integer ( int )---------------> Whole numbers

# %%
age = 26

type(age)
# Out:
# int

# %%
employees = 50

type(employees)
# Out:
# int

# %%
year = 2024

type(year)
# Out:
# int

# %% [markdown]
# ### b. Float ------------------> Number with decimal

# %%
height = 1.56

type(height)
# Out:
# float

# %%
average_sales = 12345.67

type(average_sales)
# Out:
# float

# %%
temperature = 22.5

type(temperature)
# Out:
# float

# %% [markdown]
# ### c. String ( str )----------------------->Text

# %%
name = 'olara'

type(name)
# Out:
# str

# %%
city = "Nairobi"

type(city)
# Out:
# str

# %%
message = "Welcome to Python!"

type(message)
# Out:
# str

# %% [markdown]
# ### Boolean--------------------> True or false

# %%
a = 10
b = 5

print(a > b)
print(a < b)
print (a==b)
# Out:
# True
# False
# False

# %% [markdown]
# #  3.List

# %%
fruits =['mango','banana','orenge','chery']

scores = [78,98,56,98]

my_list =[]
print(fruits)
# Out:
# ['mango', 'banana', 'orenge', 'chery']

# %%
fruits = ["apple", "banana", "orange"]

scores = [85, 90, 78, 92]

print(fruits)
print(scores[0])
# Out:
# ['apple', 'banana', 'orange']
# 85

# %%
thislist = ["apple", "banana", "cherry"]

print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#Accesing Items form the list

thislist = ["apple", "banana", "cherry"]

print(thislist[-1])
# Out:
# cherry

# %%
#Changeing Item Value from the list

thislist = ["apple", "banana", "cherry"]

thislist[1] = "blackcurrant"

print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
#Change the values "banana" and "cherry" with the values "blackcurrant" and "watermelon":

thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]

thislist[1:2] = "blackcurrant","watermelon"

print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry', 'orange', 'kiwi', 'mango']

# %%
#Change the second and third value by replacing it with one value:

thislist = ["apple", "banana", "cherry"]

thislist[1:3] = ["mango"]

print(thislist)
# Out:
# ['apple', 'mango']
