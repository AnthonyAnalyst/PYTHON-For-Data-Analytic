# %%
import pandas as pd
print('Pandas imported suscefully!!')
# Out:
# Pandas imported suscefully!!

# %% [markdown]
# # series and DataFrames

# %%
#creating a series

age= pd.Series([65,23,45,76,98,65,65,45,9,98,78,67,56,76,87,98,7,7,98,65,87,78,687,687,67])

age
# Out:
# 0      65
# 1      23
# 2      45
# 3      76
# 4      98
# 5      65
# 6      65
# 7      45
# 8       9
# 9      98
# 10     78
# 11     67
# 12     56
# 13     76
# 14     87
# 15     98
# 16      7
# 17      7
# 18     98
# 19     65
# 20     87
# 21     78
# 22    687
# 23    687
# 24     67
# dtype: int64

# %% [markdown]
# # 2. Dataframe

# %%
# creating a dataframe

data = {
    'Name': ['Amina', 'Joseph', 'Fatima', 'Samuel'],
    'Age': [28, 35, 42, 19],
    'Household_Size': [5, 7, 4, 3],
    'Zone': ['A', 'B', 'A', 'C']
}

df=pd.DataFrame(data)

df
# Out:
#      Name  Age  Household_Size Zone
# 0   Amina   28               5    A
# 1  Joseph   35               7    B
# 2  Fatima   42               4    A
# 3  Samuel   19               3    C

# %% [markdown]
# ## Loading a Datasets using a pandas
#
# **1. loading a csv files**

# %%
df= pd.read_csv("Data Set/sales.csv",encoding ="latin1")

df

# firt five rows

df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df3= pd.read_csv("Data Set/messy_sales.csv") 

df3
# Out:
#       OrderID Customer Name   product  Quantity    Price  Order Date Region
# 0        1378           NaN     Mouse       4.0  1295.53  10/26/2025   West
# 1        2780       Douglas     Mouse       1.0  1322.77    6/6/2024   East
# 2        2359         Sarah     Mouse       5.0   250.51   3/15/2024  North
# 3        2116       Stanley     Mouse       3.0    30.05    8/9/2025   West
# 4        1267        Rachel  Keyboard       3.0   296.62   3/17/2024  South
# ...       ...           ...       ...       ...      ...         ...    ...
# 1995     2733        Nicole   Monitor       3.0   703.97   12/9/2025  North
# 1996     2586        Ashley   Monitor       1.0  1406.12   10/2/2024    NaN
# 1997     1699        Andrew     Mouse       1.0  1353.34   5/28/2025   West
# 1998     1733       Shannon    Laptop       4.0   331.85   2/29/2024  North
# 1999     1428         Randy       NaN       1.0   199.31   6/13/2025  North
#
# [2000 rows x 7 columns]

# %%
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# **2. Load an Excel file (.xlsx)**

# %%
df2= pd.read_excel("Data Set/sales.xlsx") 

df2
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### 3. loading a database

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
conn= mysql.connector.connect(
    host='localhost',
    user='root',
    port= 3306,
    database='customer_behavior',
    password= 'Data-2026'
)

print("connected successfully")
# Out:
# connected successfully

# %%
df4 = pd.read_sql('SELECT * FROM customers',conn)

df4
# Out:
# C:\Users\len\AppData\Local\Temp\ipykernel_11228\3772134260.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df4 = pd.read_sql('SELECT * FROM customers',conn)
#       customer_id  age    age_group  gender item_purchased     category  \
# 0               1   55  Middle Aged    Male         Blouse     Clothing
# 1               2   19  Young Adult    Male        Sweater     Clothing
# 2               3   50  Middle Aged    Male          Jeans     Clothing
# 3               4   21  Young Adult    Male        Sandals     Footwear
# 4               5   45  Middle Aged    Male         Blouse     Clothing
# ...           ...  ...          ...     ...            ...          ...
# 3895         3896   40        Adult  Female         Hoodie     Clothing
# 3896         3897   52  Middle Aged  Female       Backpack  Accessories
# ...

# %%
df4. shape
# Out:
# (3900, 20)
